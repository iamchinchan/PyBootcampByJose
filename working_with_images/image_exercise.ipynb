# %%
from PIL import Image

# %%
mask  = Image.open("mask.png")
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
words = Image.open("word_matrix.png")
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
mask = mask.resize(words.size)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
mask.size
# Out:
# (1015, 559)

# %%
words.size
# Out:
# (1015, 559)

# %%
solve_image = words.copy()
solve_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
solve_image.paste(im = mask,box=(0,0))

# %%
solve_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
solve_image = words.copy()
mask.putalpha(125)
solve_image.paste(im=mask, box=(0,0),mask = mask)

# %%
solve_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

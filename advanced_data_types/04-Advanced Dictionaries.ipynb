# %% [markdown]
# # Advanced Dictionaries
# Unlike some of the other Data Structures we've worked with, most of the really useful methods available to us in Dictionaries have already been explored throughout this course. Here we will touch on just a few more for good measure:

# %% [markdown]
# ## Dictionary Comprehensions
#
# Just like List Comprehensions, Dictionary Data Types also support their own version of comprehension for quick creation. It is not as commonly used as List Comprehensions, but the syntax is:

# %%
{x:x**2 for x in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
dict1 = {x:x**2 for x in range(10)}

# %%
dict1['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict1['1']
#
# KeyError: '1'

# %%
dict1[1]
# Out:
# 1

# %%
{k:v**2 for k,v in zip(['a','b'],range(2))}
# Out:
# {'a': 0, 'b': 1}

# %% [markdown]
# One of the reasons it is not as common is the difficulty in structuring key names that are not based off the values.

# %% [markdown]
# ## Iteration over keys, values, and items
# Dictionaries can be iterated over using the keys(), values() and items() methods. For example:

# %%
d = {'k1':1,'k2':2}

# %%
for k in d.keys():
    print(k)
# Out:
# k1
# k2

# %%
for k in d:
  print(k)
# Out:
# k1
# k2

# %%
d.keys
# Out:
# <function dict.keys()>

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
d.values()
# Out:
# dict_values([1, 2])

# %%
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2)])

# %%
type(d.items())
# Out:
# dict_items

# %%
'k1' in d
# Out:
# True

# %%
's' in d
# Out:
# False

# %%
for v in d.values():
    print(v)
# Out:
# 1
# 2

# %%
for item in d.items():
    print(item)
# Out:
# ('k1', 1)
# ('k2', 2)

# %%
for k,v in d.items():
  print(k,v)
# Out:
# k1 1
# k2 2

# %% [markdown]
# # Viewing keys, values and items
# By themselves the keys(), values() and items() methods return a dictionary *view object*. This is not a separate list of items. Instead, the view is always tied to the original dictionary.

# %%
key_view = d.keys()

key_view
# Out:
# dict_keys(['k1', 'k2'])

# %%
d['k3'] = 3
#we can add a key on the go
d
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
key_view
#its a pointer
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d={'k1': 1, 'k2': 2}
print(d)
keys = d.keys()
values = d.values()
items = d.items()
print(f"keys are: {keys}\nVAlues are : {values}\nAnd items are: {items}")
d['k3']=3
print(f"updated d is: {d}")
print(f"updated views are: ")
print(f"keys are: {keys}\nVAlues are : {values}\nAnd items are: {items}")
# Out:
# {'k1': 1, 'k2': 2}
# keys are: dict_keys(['k1', 'k2'])
# VAlues are : dict_values([1, 2])
# And items are: dict_items([('k1', 1), ('k2', 2)])
# updated d is: {'k1': 1, 'k2': 2, 'k3': 3}
# updated views are:
# keys are: dict_keys(['k1', 'k2', 'k3'])
# VAlues are : dict_values([1, 2, 3])
# And items are: dict_items([('k1', 1), ('k2', 2), ('k3', 3)])

# %%
for k in keys:
  print(k)
# Out:
# k1
# k2
# k3

# %%
for k in keys:
  print(k)
# Out:
# k1
# k2
# k3

# %%
#not exhausted:
# its a view not an iterator(one time use)
#its an iterable

# %%
# 'keys' is a View (Reusable)
keys = d.keys() 

# This 'it' is now a real Iterator (One-time use)
it = iter(keys) 

print(next(it)) # Gives you the first key
print(next(it)) # Gives you the second key...
# Once you finish this, 'it' is dead, but 'keys' is still alive!
# Out:
# k1
# k2

# %%
keys
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %% [markdown]
# Great! You should now feel very comfortable using the variety of methods available to you in Dictionaries!

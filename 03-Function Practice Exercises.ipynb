# %% [markdown]
# # Function Practice Exercises
#
# Problems are arranged in increasing difficulty:
# * Warmup - these can be solved using basic comparisons and methods
# * Level 1 - these may involve if/then conditional statements and simple methods
# * Level 2 - these may require iterating over sequences, usually with some kind of loop
# * Challenging - these will take some creativity to solve

# %% [markdown]
# ## WARMUP SECTION:

# %% [markdown]
# #### LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers *if* both numbers are even, but returns the greater if one or both numbers are odd
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(a,b):
    return min(a,b) if (a%2==0 and b%2==0) else max(a,b)

# def lesser_of_two_evens(a,b):
#     return (max(a,b),min(a,b))[a%2==0 and b%2==0]

# %%
# Check
lesser_of_two_evens(2,4)
# Out:
# 2

# %%
# Check
lesser_of_two_evens(2,5)
# Out:
# 5

# %%
lesser_of_two_evens(5,7)
# Out:
# 7

# %%
lesser_of_two_evens(3,4)
# Out:
# 4

# %% [markdown]
# #### ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
#     animal_crackers('Levelheaded Llama') --> True
#     animal_crackers('Crazy Kangaroo') --> False

# %%
# def animal_crackers(text):
#     words = text.split()
#     return words[0][0]==words[1][0]

def animal_crackers(text):
    w1,w2,*others = text.lower().split()
    return w1[0]==w2[0]

# %%
# Check
# animal_crackers('Levelheaded')

# %%
# Check
animal_crackers('Levelheaded Llama')
# Out:
# True

# %%
# Check
animal_crackers('Crazy Kangaroo')
# Out:
# False

# %% [markdown]
# #### MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 *or* if one of the integers is 20. If not, return False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
# def makes_twenty(n1,n2):
#     return (n1==20) or (n2==0) or (n1+n2==20)

def makes_twenty(a,b):
    return a==20 or b==20 or a+b==20

# %%
# Check
makes_twenty(20,10)
# Out:
# True

# %%
# Check
makes_twenty(2,3)
# Out:
# False

# %% [markdown]
# # LEVEL 1 PROBLEMS

# %% [markdown]
# #### OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
# def old_macdonald(name):
#     return name.capitalize()[:3] + name[3].upper()+name[4:]

# %%
def old_macdonald(name):
    if len(name) > 3:
        return name[:3].capitalize() + name[3:].capitalize()
    else:
        return 'Name is too short!'

# %%
# Check
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %% [markdown]
# #### MASTER YODA: Given a sentence, return a sentence with the words reversed
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: The .join() method may be useful here. The .join() method allows you to join together strings in a list with some connector string. For example, some uses of the .join() method:
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# This means if you had a list of words you wanted to turn back into a sentence, you could just join them with a single space string:
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def master_yoda(text):
    # print(text.split()[::-1])
     return ' '.join(text.split()[::-1])

# %%
# Check
master_yoda('I am home')
# Out:
# 'home am I'

# %%
# Check
master_yoda('We are ready')
# Out:
# 'ready are We'

# %% [markdown]
# #### ALMOST THERE: Given an integer n, return True if n is within 10 of either 100 or 200
#
#     almost_there(90) --> True
#     almost_there(104) --> True
#     almost_there(150) --> False
#     almost_there(209) --> True
#
# NOTE: `abs(num)` returns the absolute value of a number

# %%
def almost_there(n):
    return abs(n-100)<=10 or abs(n-200)<=10

# %%
almost_there(90)
# Out:
# True

# %%
# Check
almost_there(104)
# Out:
# True

# %%
# Check
almost_there(150)
# Out:
# False

# %%
# Check
almost_there(209)
# Out:
# True

# %% [markdown]
# # LEVEL 2 PROBLEMS

# %% [markdown]
# #### FIND 33:
#
# Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.
#
#     has_33([1, 3, 3]) → True
#     has_33([1, 3, 1, 3]) → False
#     has_33([3, 1, 3]) → False

# %%
def has_33(nums):
    for n in range(len(nums)-1):
        # if(nums[n]==3 and nums[n+1]==3):
        # or
        if nums[n:n+2] == [3,3]:
            return True
    return False
# has more better avg tc

# %%
# # this is nottttt another way to do this:
# def has_33(nums):
#     strlst = [str(num) for num in nums]
#     return '33' in ''.join(strlst)

# this is wrongggggggggggggg as 13,3 wll give true when i should nott

# %%
# Check
has_33([1, 3, 3])
# Out:
# True

# %%
# Check
has_33([1, 3, 1, 3])
# Out:
# False

# %%
# Check
has_33([3,3, 1, 3])
# Out:
# True

# %%
# Check
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# #### PAPER DOLL: Given a string, return a string where for every character in the original there are three characters
#     paper_doll('Hello') --> 'HHHeeellllllooo'
#     paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def paper_doll(text):
    return ''.join([letter*3 for letter in text])

# %% [markdown]
# # OR

# %%
# def paper_doll(text):
#     result = ''
#     for char in text:
#         result += char * 3
#     return result

# %%
# Check
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
# Check
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# #### BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 *and* there's an eleven, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
def blackjack(a,b,c):
    lst = [a,b,c]
    # print(lst)
    sm =  sum(lst)
    # print(sm)
    if(sm<=21):
        return sm
    else:
        while sm>21:
            if 11 in lst:
                indexof11 = lst.index(11)
                lst[indexof11] = 1
            else:
                return "BUST"    
            sm=sum(lst)
        else:
            return sm

# %%
blackjack(11,11,11)
# Out:
# 13

# %%
# Check
blackjack(5,6,7)
# Out:
# 18

# %%
# Check
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
# Check
blackjack(9,9,11)
# Out:
# 19

# %% [raw]
# # or if you can only remove 11 at max one time then:

# %%
def blackjack(a,b,c):
    
    if sum((a,b,c)) <= 21:
        return sum((a,b,c))
    elif sum((a,b,c)) <=31 and 11 in (a,b,c):
        return sum((a,b,c)) - 10
    else:
        return 'BUST'

# %%
blackjack(11,11,11)
# Out:
# 'BUST'

# %%
# Check
blackjack(5,6,7)
# Out:
# 18

# %%
# Check
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
# Check
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# #### SUMMER OF '69: Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extending to the next 9 (every 6 will be followed by at least one 9). Return 0 for no numbers.
#
#     summer_69([1, 3, 5]) --> 9
#     summer_69([4, 5, 6, 7, 8, 9]) --> 9
#     summer_69([2, 1, 6, 9, 11]) --> 14

# %%
# def summer_69(arr):
#     lst = arr
#     i=0
#     while i<len(lst):
#         if lst[i]==6:
#             nine_index = lst.index(9,i)+1
#             lst[i:nine_index]=[0]*(nine_index-i)
#         else:
#             pass
#         i+=1

#     return sum(lst)

# %%
# def summer_69(arr):
#     lst = arr
#     i=0
#     while i<len(lst):
#         if lst[i]==6:
#             while lst[i]!=9:
#               lst[i]=0
#               i+=1
#             lst[i]=0
#         else:
#             pass
#         i+=1

#     return sum(lst)

# %%
# def summer_69(arr):
#     result=0
#     i=0
#     while i<= len(arr)-1:
#         if(arr[i]==6):
#             while(arr[i]!=9):
#                 i+=1
#         else:
#             result+=arr[i]
#         i+=1
#     return result

# %%
def summer_69(arr):
  active=False
  total=0;
  for num in arr:
    if num==6: active= True
    if not active: total+=num
    if num==9: active=False
  return total

# %%
# Check
summer_69([6, 1, 6, 9,6,7,8,9,11])
# Out:
# 11

# %%
# Check
summer_69([1, 3, 5])
# Out:
# 9

# %%
# Check
summer_69([4, 5, 6, 7, 8, 9])
# Out:
# 9

# %%
# Check
summer_69([2, 1, 6, 9, 11])
# Out:
# 14

# %%
# Check
summer_69([6, 1, 6, 9, 11])
# Out:
# 11

# %% [markdown]
# # CHALLENGING PROBLEMS

# %% [markdown]
# #### SPY GAME: Write a function that takes in a list of integers and returns True if it contains 007 in order
#
#      spy_game([1,2,4,0,0,7,5]) --> True
#      spy_game([1,0,2,4,0,5,7]) --> True
#      spy_game([1,7,2,0,4,5,0]) --> False

# %%
# def spy_game(nums):
#   for i in range(len(nums)-2):
#     if nums[i:i+3]==[0,0,7]:
#       return True
#     else: return False

# works if question would have been to find a continous 007 but nvm

# %%
# def spy_game(nums):
#     nums = [str(num) for  num in nums] 
#     index=0
#     while index<len(nums):
#         if(nums[index]!='0' and nums[index]!='7'):
#             nums.remove(nums[index])
#             index-=1
#         index+=1
#     return '007' in ''.join(nums)

# %% [markdown]
# # or

# %%
# # better way to do it:
#  # really awesome soln by author:
# def spy_game(nums):
#     code = ['x',7,0,0]
#     for num in nums:
#         # no need to worry about out of index when length will be 0 as there a 'x' char which will always be there in the list
#         if num == code[-1]:
#             code.pop()
#     return len(code)==1

# %% [markdown]
# # or

# %%
# #another better way to do it without 'x' in code list:
#  # really awesome soln by author:
# def spy_game(nums):
#     code = [7,0,0]
#     for num in nums:
#         if not code:
#             return True
#         if num == code[-1]:
#             code.pop()
#     return len(code)==0

# %%
def spy_game(nums):
  i=0;
  code = [0,0,7]
  for n in nums:
    if n==code[i]:
      i+=1
      if i==len(code): return True
  return False

# %%
# Check
spy_game([1,2,4,0,7,0,8,7,5])
# Out:
# True

# %%
# Check
spy_game([1,2,4,0,0,7,5])
# Out:
# True

# %%
# Check
spy_game([1,0,2,4,0,5,7])
# Out:
# True

# %%
# Check
spy_game([1,7,2,0,4,5,0])
# Out:
# False

# %% [markdown]
# #### COUNT PRIMES: Write a function that returns the *number* of prime numbers that exist up to and including a given number
#     count_primes(100) --> 25
#
# By convention, 0 and 1 are not prime.

# %%
lst = [True]* (2**2)+[False]
lst
# print((10**9)**0.5)
# Out:
# [True, True, True, True, False]

# %%
# # lets just create a sieve of prime numbers uptil 10**9
# import math
# MAX = 10**4
# sieve= [False]+[False]+[True]*(MAX-1)
# # total length of sieve will be MAX+1
# index1=2
# while index1 <=math.ceil(MAX**0.5):
#     if sieve[index1]:
#         # if sieve value at that index is still true that means it is a prime number itself
#         index2 = index1*index1
#         while index2 <= MAX:
#             sieve[index2]=False
#             index2+=index1
#     index1+=1
# # for index,status in enumerate(sieve):
# #     print(f" {index} :  {status}")

# %%
# def count_primes(num):
#     result=1
#     if(num<2):
#         return 0
#     for index in range(3,num+1,2):
#         if sieve[index]:
#             result+=1
#         else:
#             pass
#     return result

# %% [markdown]
# BONUS: Here's a faster version that makes use of the prime numbers we're collecting as we go!

# %%
# def count_primes(num):
#     primes = [2]
#     x = 3
#     if num < 2:
#         return 0
#     while x <= num:
#         for y in primes:  # use the primes list! yup that makes sense
#             if x%y == 0:
#                 x += 2
#                 break
#         else:
#             primes.append(x)
#             x += 2
#     print(primes)
#     return len(primes)

# %%
test_inputs = [
    -5, 0, 1, 2, 3, 4, 9, 11,           # Edge Cases
    100, 1000, 7919, 10000, 100000,      # Small to Medium Scale
    1000000, 10000000, 100000000,        # Large Scale (10^6, 10^7, 10^8)
    1000000000                          # Boss Level (10^9)
]

# Matching Expected Answers (pi(x) values)
test_answers = [
    0, 0, 0, 1, 2, 2, 4, 5,              # Edge Answers
    25, 168, 1000, 1229, 9592,           # Scale Answers
    78498, 664579, 5761455,              # Large Scale Answers
    50847534                             # Boss Level Answer
]
# Out:
# [50847534,
#  0,
#  0,
#  1,
#  2,
#  2,
#  4,
#  5,
#  25,
#  168,
#  1000,
#  1229,
#  9592,
#  78498,
#  664579,
#  5761455,
#  50847534]

# %%
max = 10**9
isPrime=[True]*(max+1)
def isPrimeCheck():

    isPrime[0] = isPrime[1]=False
    isPrime[4::2] = [False]*((max-4)//2+1)
    for num in range(3,int(max**0.5)+1,2):
      if isPrime[num]:
        start=num*num
        step = 2*num
        isPrime[start:max+1:step]=[False]*((max-start)//step+1)
  
isPrimeCheck()

# %%
# import itertools
def count_primes(num):
  if num<0: return 0
  return sum(isPrime[0:num+1])
  # return sum(1 for i in range(num+1) if isPrime[i])
  # return sum(itertools.islice(isPrime,num+1))

# %%
#check]
answers = [count_primes(num) for num in test_inputs]

# %%
print(answers)
# Out:
# [0, 0, 0, 1, 2, 2, 4, 5, 25, 168, 1000, 1229, 9592, 78498, 664579, 5761455, 50847534]

# %%
answers==test_answers
# Out:
# True

# %%
# Check
count_primes(100)
# Out:
# 25

# %% [markdown]
# ### Just for fun:
# #### PRINT BIG: Write a function that takes in a single letter, and returns a 5x5 representation of that letter
#     print_big('a')
#
#     out:   *
#           * *
#          *****
#          *   *
#          *   *
# HINT: Consider making a dictionary of possible patterns, and mapping the alphabet to specific 5-line combinations of patterns. <br>For purposes of this exercise, it's ok if your dictionary stops at "E".

# %%
def print_big(letter):
    pass

# %%
print_big('a')

# %%
def myfunc(str):
    return ''.join([str[index].upper() if index%2==0 else str[index].lower() for index in range(len(str))])

# %%
myfunc('waefwefawfawfw')
# Out:
# 'WaEfWeFaWfAwFw'

# %% [markdown]
# ## Great Job!

# %% [markdown]
# # `*args` and `**kwargs`
#
# Work with Python long enough, and eventually you will encounter `*args` and `**kwargs`. These strange terms show up as parameters in function definitions. What do they do? Let's review a simple function:

# %%
# lets check if we can pass set or dict.values() iterable in sum fn?
st1 = set({1,2,3,4,5,3})
print(f"sum of st1 is :  {sum(st1)}")

dict1 =  {
    "score1":40,
    "score2":60
}
print(list(dict1.values()))
print(dict1.values())
print(f"sum of values in a dictionary(dict1) : {sum(dict1.values())}")
# Out:
# sum of st1 is :  15
# [40, 60]
# dict_values([40, 60])
# sum of values in a dictionary(dict1) : 100

# %%
def myfunc(a,b):
    return sum((a,b))*.05
    # return sum(a,b)*.05 # gives erorr be careful, sum fn accpets list or a tuple so an ietrable
    # return sum([a,b]) 
    

myfunc(40,60)
# Out:
# 5.0

# %% [markdown]
# This function returns 5% of the sum of **a** and **b**. In this example, **a** and **b** are *positional* arguments; that is, 40 is assigned to **a** because it is the first argument, and 60 to **b**. Notice also that to work with multiple positional arguments in the `sum()` function we had to pass them in as a tuple.
#
# What if we want to work with more than two numbers? One way would be to assign a *lot* of parameters, and give each one a default value.

# %%
def myfunc(a=0,b=0,c=0,d=0,e=0):
    return sum((a,b,c,d,e))*.05

myfunc(40,60,20)
# Out:
# 6.0

# %% [markdown]
# Obviously this is not a very efficient solution, and that's where `*args` comes in.
#
# ## `*args`
#
# When a function parameter starts with an asterisk, it allows for an *arbitrary number* of arguments, and the function takes them in as a tuple of values. Rewriting the above function:

# %%
def myfunc(*args):
    print(args)
    return sum(args)*.05

myfunc(40,60,20)
# Out:
# (40, 60, 20)
# 6.0

# %% [markdown]
# Notice how passing the keyword "args" into the `sum()` function did the same thing as a tuple of arguments.
#
# It is worth noting that the word "args" is itself arbitrary - any word will do so long as it's preceded by an asterisk. To demonstrate this:

# %%
def myfunc(*spam):
    print(f"spam is  : {spam}")
    
    return sum(spam)*.05

myfunc(40,60,20)
# Out:
# spam is  : (40, 60, 20)
# 6.0

# %%
def myfunc(*spam):
    return sum(spam)*.05

# myfunc(40,60,20,(10,10))
myfunc(40,60,40,60)
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'
# Out:
# 10.0

# %% [markdown]
# ## `**kwargs`
#
# Similarly, Python offers a way to handle arbitrary numbers of *keyworded* arguments. Instead of creating a tuple of values, `**kwargs` builds a dictionary of key/value pairs. For example:

# %%
def myfunc(**kwargs):
    print(f"kwargs is: {kwargs}")
    if 'fruit' in kwargs:
        print(f"My favorite fruit is {kwargs['fruit']}")  # review String Formatting and f-strings if this syntax is unfamiliar
    else:
        print("I don't like fruit")
        
myfunc(fruit='pineapple',name="jatin")
# Out:
# kwargs is: {'fruit': 'pineapple', 'name': 'jatin'}
# My favorite fruit is pineapple

# %%
myfunc()
# Out:
# kwargs is: {}
# I don't like fruit

# %% [markdown]
# ## `*args` and `**kwargs` combined
#
# You can pass `*args` and `**kwargs` into the same function, but `*args` have to appear before `**kwargs`

# %%
def myfunc(a,*args,name, **kwargs):
    if 'fruit' in kwargs and 'juice' in kwargs: # did not know i could combine 2 check with and & in (bcz we cant, error in author's code)
        print(args,kwargs)
        print(f"I like {' and '.join(args)} and my favorite fruit is {kwargs['fruit']}")
        # print(f"I like {' and '.join(str(arg) for arg in args )} and my favorite fruit is {kwargs['fruit']}") # works fine
        print(f"I like {' and '.join(args)} and my favorite fruit is {kwargs['fruit']}")  # error (TypeError: sequence item 2: expected str instance, tuple found)
        print(f"May I have some {kwargs['juice']} juice?")
        # print(kwargs['name'])
    else:
        print("not found")
    print(f"name is {name}")
    print(f"a is {a}")
        
myfunc('eggs','spam',"bla bla",name="jatin",fruit=["cherirs","berries"],juice=['orange',{"juice1":"pineapple"}])
# myfunc('eggs','spam',("tea","milk"),fruit='cherries',juice='orange')
# Out:
# ('spam', 'bla bla') {'fruit': ['cherirs', 'berries'], 'juice': ['orange', {'juice1': 'pineapple'}]}
# I like spam and bla bla and my favorite fruit is ['cherirs', 'berries']
# I like spam and bla bla and my favorite fruit is ['cherirs', 'berries']
# May I have some ['orange', {'juice1': 'pineapple'}] juice?
# name is jatin
# a is eggs

# %% [markdown]
# Placing keyworded arguments ahead of positional arguments raises an exception:

# %%
myfunc(fruit='cherries',juice='orange','eggs','spam')
# Out:
#   Cell In[20], line 1
#     myfunc(fruit='cherries',juice='orange','eggs','spam')
#                                                         ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# As with "args", you can use any name you'd like for keyworded arguments - "kwargs" is just a popular convention.
#
# That's it! Now you should understand how `*args` and `**kwargs` provide the flexibilty to work with arbitrary numbers of arguments!

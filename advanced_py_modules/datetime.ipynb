# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-04-24 23:46:12.455594

# %%
time1 = datetime.time(21,45)

# %%
print(time1)
# Out:
# 21:45:00

# %%
print(time1.minute)
print(time1.hour)
print(time1.second)
print(time1.microsecond)
# Out:
# 45
# 21
# 0
# 0

# %%
time2 = datetime.time(21,45,56,780)

# %%
print(time2)
# Out:
# 21:45:56.000780

# %%
from datetime import datetime
time1 = datetime.time(21,45)
#wont work as now datetime here is not a module but a class already imported as class from datetime module
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from datetime import datetime
# ----> 2 time1 = datetime.time(21,45)
#       3 #wont work as now datetime here is not a module but a class already imported as class from datetime module
#
# TypeError: descriptor 'time' for 'datetime.datetime' objects doesn't apply to a 'int' object

# %%
from datetime import datetime,date,time

# %%
date1 = date(2026,4,23)

# %%
print(date1)
# Out:
# 2026-04-23

# %%
date1.day
# Out:
# 23

# %%
date1.month
# Out:
# 4

# %%
date1.year
# Out:
# 2026

# %%
date2 = date(2022,2,23)

# %%
date2
# Out:
# datetime.date(2022, 2, 23)

# %%
date1-date2
# Out:
# datetime.timedelta(days=1520)

# %%
result = date1-date2

# %%
type(result)
# Out:
# datetime.timedelta

# %%
result
# Out:
# datetime.timedelta(days=1520)

# %%
print(result)
# Out:
# 1520 days, 0:00:00

# %%
result.days
# Out:
# 1520

# %%
result.seconds
# Out:
# 0

# %%
date1 = date1.replace(year=2025)

# %%
date1
# Out:
# datetime.date(2025, 4, 23)

# %%
result = date1-date2
print(result)
# Out:
# 1155 days, 0:00:00

# %%
datetime1 = datetime.now()

# %%
print(datetime)
# Out:
# <class 'datetime.datetime'>

# %%
print(datetime1)
# Out:
# 2026-04-24 23:52:05.635165

# %%
print(type(datetime1))
# Out:
# <class 'datetime.datetime'>

# %%
type(date1)
# Out:
# datetime.date

# %%
type(datetime1)
# Out:
# datetime.datetime

# %%
print(type(date1))
# Out:
# <class 'datetime.date'>

# %%
datetime2 = datetime(2022,5,23,23,45,56)

# %%
datetime2
# Out:
# datetime.datetime(2022, 5, 23, 23, 45, 56)

# %%
print(datetime2)
# Out:
# 2022-05-23 23:45:56

# %%
datetime1-datetime2
# Out:
# datetime.timedelta(days=1432, seconds=369, microseconds=635165)

# %%
datetimediff = datetime1- datetime2

# %%
type(datetimediff)
# Out:
# datetime.timedelta

# %%
datetimediff
# Out:
# datetime.timedelta(days=1432, seconds=369, microseconds=635165)

# %%
print(datetimediff)
# Out:
# 1432 days, 0:06:09.635165

# %%
datetimediff.seconds
# Out:
# 369

# %%
datetimediff.days
# Out:
# 1432

# %%
today  = date.today()

# %%
print(today)
# Out:
# 2026-04-24

# %%
today.ctime()
# Out:
# 'Fri Apr 24 00:00:00 2026'

# %%
datetime1.ctime()
# Out:
# 'Fri Apr 24 23:52:05 2026'

# %%
datetime2.ctime()
# Out:
# 'Mon May 23 23:45:56 2022'

# %%
type(today)
# Out:
# datetime.date

# %%
print(today)
# Out:
# 2026-04-24

# %%
print(type(today))
# Out:
# <class 'datetime.date'>

# %% [markdown]
# # datetime module
#
# Python has the datetime module to help deal with timestamps in your code. Time values are represented with the time class. Times have attributes for hour, minute, second, and microsecond. They can also include time zone information. The arguments to initialize a time instance are optional, but the default of 0 is unlikely to be what you want.
#
# ## time
# Let's take a look at how we can extract time information from the datetime module. We can create a timestamp by specifying datetime.time(hour,minute,second,microsecond)

# %%
import datetime

t = datetime.time(4, 20, 1)

# Let's show the different components
print(t)
print('hour  :', t.hour)
print('minute:', t.minute)
print('second:', t.second)

print('microsecond:', t.microsecond)
print('tzinfo:', t.tzinfo)
# Out:
# 04:20:01
# hour  : 4
# minute: 20
# second: 1
# microsecond: 0
# tzinfo: None

# %% [markdown]
# Note: A time instance only holds values of time, and not a date associated with the time.
#
# We can also check the min and max values a time of day can have in the module:

# %%
t1= datetime.time(1,10,0)
t2= datetime.time(1,5,0)
# t1-t2 # not supported for onlt time, but upported for date and datetime
# print(t1-t2)

# %%
print('Earliest  :', datetime.time.min)
print('Latest    :', datetime.time.max)
print('Resolution:', datetime.time.resolution)
# Out:
# Earliest  : 00:00:00
# Latest    : 23:59:59.999999
# Resolution: 0:00:00.000001

# %% [markdown]
# The min and max class attributes reflect the valid range of times in a single day.

# %% [markdown]
# ## Dates
# datetime (as you might suspect) also allows us to work with date timestamps. Calendar date values are represented with the date class. Instances have attributes for year, month, and day. It is easy to create a date representing today’s date using the today() class method.
#
# Let's see some examples:

# %%
today = datetime.date.today()
print(today)
print('ctime:', today.ctime())
print('tuple:', today.timetuple())
print('ordinal:', today.toordinal())
print('Year :', today.year)
print('Month:', today.month)
print('Day  :', today.day)
# Out:
# 2026-04-25
# ctime: Sat Apr 25 00:00:00 2026
# tuple: time.struct_time(tm_year=2026, tm_mon=4, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=115, tm_isdst=-1)
# ordinal: 739731
# Year : 2026
# Month: 4
# Day  : 25

# %% [markdown]
# As with time, the range of date values supported can be determined using the min and max attributes.

# %%
print('Earliest  :', datetime.date.min)
print('Latest    :', datetime.date.max)
print('Resolution:', datetime.date.resolution)
# Out:
# Earliest  : 0001-01-01
# Latest    : 9999-12-31
# Resolution: 1 day, 0:00:00

# %% [markdown]
# Another way to create new date instances uses the replace() method of an existing date. For example, you can change the year, leaving the day and month alone.

# %%
d1 = datetime.date(2015, 3, 11)
print('d1:', d1)

d2 = d1.replace(year=1990)
#not a in-place method
print('d2:', d2)

print(f"d1 is still :",d1)
# Out:
# d1: 2015-03-11
# d2: 1990-03-11
# d1 is still : 2015-03-11

# %% [markdown]
# # Arithmetic
# We can perform arithmetic on date objects to check for time differences. For example:

# %%
d1
# Out:
# datetime.date(2015, 3, 11)

# %%
d2
# Out:
# datetime.date(1990, 3, 11)

# %%
d3 = d1-d2

# %%
d3
# Out:
# datetime.timedelta(days=9131)

# %%
d3.days
# Out:
# 9131

# %%
d3.total_seconds()
# Out:
# 788918400.0

# %%
d1 = datetime.datetime(2000,2,22,20,50,1)
d2 = datetime.datetime(2001,2,22,21,10,3)
d3=d2-d1
d3
# calculating leap year
# Out:
# datetime.timedelta(days=366, seconds=1202)

# %%
d3.days
# Out:
# 366

# %%
d3.seconds
# Out:
# 1202

# %%
d3.total_seconds()
# Out:
# 31623602.0

# %%
d3.resolution
# Out:
# datetime.timedelta(microseconds=1)

# %%
d3.max
# Out:
# datetime.timedelta(days=999999999, seconds=86399, microseconds=999999)

# %%
d3.min
# Out:
# datetime.timedelta(days=-999999999)

# %% [markdown]
# This gives us the difference in days between the two dates. You can use the timedelta method to specify various units of times (days, minutes, hours, etc.)
#
# Great! You should now have a basic understanding of how to use datetime with Python to work with timestamps in your code!

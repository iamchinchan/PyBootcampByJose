# %%
1+1

# %%
2**3

# %%
3/2

# %%
7%4
7/4

# %%
13*14

# %%
15*16

# %%
0.1+0.2-0.3

# %%
list =5

# %%
list

# %%
name="jatin"
name

# %%
type(name)

# %%
a= 4.7
b= int(a)
print(a,b)

# %%
name='hi hr"e'
print(name)
name='hi thrre'
print(name)
name = "hi g'g"
print(name)

# %%
s = "hello"
print(s[-1])
print(s[-5],s[0])
# print(s[5])
# print(s[-6])

# %%
print("hi /nThere")
print("hi \nThere")

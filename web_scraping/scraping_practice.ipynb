# %%
authors={}

# %%
type(authors)
# Out:
# dict

# %%
authors.add(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 authors.add(1)
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
authors=set()

# %%
type(authors)
# Out:
# set

# %%
authors.add(1)

# %%
authors
# Out:
# {1}

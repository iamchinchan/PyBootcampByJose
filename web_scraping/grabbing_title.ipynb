# %%
import requests

# %%
page_data = requests.get("https://www.example.com/")

# %%
page_data
# Out:
# <Response [200]>

# %%
print(page_data)
# Out:
# <Response [200]>

# %%
type(page_data)
# Out:
# requests.models.Response

# %%
page_data.text
# Out:
# '<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>\n'

# %%
type(page_data.text)
# Out:
# str

# %%
print(page_data.text)
# Out:
# <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(page_data.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Example Domain</title><meta content="width=device-width, initial-scale=1" name="viewport"/><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Example Domain</title><meta content="width=device-width, initial-scale=1" name="viewport"/><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>

# %%
title = soup.select("title")

# %%
title
# Out:
# [<title>Example Domain</title>]

# %%
type(title)
# Out:
# bs4.element.ResultSet

# %%
print(title)
# Out:
# [<title>Example Domain</title>]

# %%
title[0]
# Out:
# <title>Example Domain</title>

# %%
single_title = title[0]

# %%
single_title
# Out:
# <title>Example Domain</title>

# %%
print(single_title)
# Out:
# <title>Example Domain</title>

# %%
type(single_title)
# Out:
# bs4.element.Tag

# %%
title_text = single_title.getText()

# %%
print(title_text)
# Out:
# Example Domain

# %%
type(title_text)
# Out:
# str

# %%
paragraphs = soup("p")

# %%
paragraphs
# Out:
# [<p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p>,
#  <p><a href="https://iana.org/domains/example">Learn more</a></p>]

# %%
len(paragraphs)
# Out:
# 2

# %%
for p in paragraphs:
  print(p)
# Out:
# <p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p>
# <p><a href="https://iana.org/domains/example">Learn more</a></p>

# %%
for p in paragraphs:
  print(f"paragraphs Text is : {p.getText()}")
# Out:
# paragraphs Text is : This domain is for use in documentation examples without needing permission. Avoid use in operations.
# paragraphs Text is : Learn more

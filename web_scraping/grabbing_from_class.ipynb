# %%
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

# %%
url="https://en.wikipedia.org/wiki/Nathuram_Godse"

# %%
web_page = requests.get(url, headers=headers)

# %%
type(web_page)
# Out:
# requests.models.Response

# %%
print(web_page)
# Out:
# <Response [200]>

# %%
web_page
# Out:
# <Response [200]>

# %%
web_page.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Nathuram Godse - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabl
# ...

# %%
print(web_page.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Nathuram Godse - Wikipedia</title>
# ...

# %%
import bs4

# %%
soup  = bs4.BeautifulSoup(web_page.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Nathuram Godse - Wikipedia</title>
# ...

# %%
title = soup.select('title')

# %%
title
# Out:
# [<title>Nathuram Godse - Wikipedia</title>]

# %%
links = soup.select(".vector-toc-text")

# %%
links
# Out:
# [<div class="vector-toc-text">(Top)</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">1</span>
#  <span>Early life</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2</span>
#  <span>Political career and beliefs</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3</span>
#  <span>RSS membership</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">4</span>
#  <span>Assassination of Mahatma Gandhi</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">5</span>
#  <span>Trial and execution</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">6</span>
#  <span>Aftermath</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">7</span>
#  <span>Terrorist act</span>
#  </div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">8</span>
# ...

# %%
links[0]
# Out:
# <div class="vector-toc-text">(Top)</div>

# %%
len(links)
# Out:
# 13

# %%
links[0].get_text()
# Out:
# '(Top)'

# %%
links[0].getText()
# Out:
# '(Top)'

# %%
links[0].text
# Out:
# '(Top)'

# %%
for link in links:
  print(link.text)
# Out:
# (Top)
#
# 1
# Early life
#
#
# 2
# Political career and beliefs
#
#
# 3
# RSS membership
#
#
# 4
# Assassination of Mahatma Gandhi
#
#
# 5
# Trial and execution
#
#
# 6
# Aftermath
#
#
# 7
# Terrorist act
#
#
# 8
# Attempts at image rehabilitation
#
#
# 9
# In popular culture
#
#
# 10
# Notes
#
#
# 11
# Bibliography
#
#
# 12
# External links

# %%
links[1]
# Out:
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>
# <span>Early life</span>
# </div>

# %%
links = soup.select(".vector-toc-text > span:nth-of-type(2)")

# %%
links
# Out:
# [<span>Early life</span>,
#  <span>Political career and beliefs</span>,
#  <span>RSS membership</span>,
#  <span>Assassination of Mahatma Gandhi</span>,
#  <span>Trial and execution</span>,
#  <span>Aftermath</span>,
#  <span>Terrorist act</span>,
#  <span>Attempts at image rehabilitation</span>,
#  <span>In popular culture</span>,
#  <span>Notes</span>,
#  <span>Bibliography</span>,
#  <span>External links</span>]

# %%
len(links)
# Out:
# 12

# %%
pattern  = ".vector-toc-text > span:nth-of-type(2)"

# %%
for topic in soup.select(pattern):
  print(topic.text)
# Out:
# Early life
# Political career and beliefs
# RSS membership
# Assassination of Mahatma Gandhi
# Trial and execution
# Aftermath
# Terrorist act
# Attempts at image rehabilitation
# In popular culture
# Notes
# Bibliography
# External links

# %%
#vector-toc-link
#vector-toc-text
#.vector-toc-text > span:nth-of-type(2)

# %% [markdown]
# # Functions and Methods Homework
#
# Complete the following questions:
# ____
# **Write a function that computes the volume of a sphere given its radius.**
# <p>The volume of a sphere is given as $$\frac{4}{3} πr^3$$</p>

# %%
import math
def vol(rad):
    return (4/3)*math.pi*(rad**3)

# %%
# Check
vol(2)
# Out:
# 33.510321638291124

# %% [markdown]
# ___
# **Write a function that checks whether a number is in a given range (inclusive of high and low)**

# %%
def ran_check(num,low,high):
   return low<= num <= high

# %%
# Check
ran_check(5,2,7)
# Out:
# True

# %% [markdown]
# If you only wanted to return a boolean:

# %%
def ran_bool(num,low,high):
    pass

# %%
ran_bool(3,1,10)

# %% [markdown]
# ____
# **Write a Python function that accepts a string and calculates the number of upper case letters and lower case letters.**
#
#     Sample String : 'Hello Mr. Rogers, how are you this fine Tuesday?'
#     Expected Output :
#     No. of Upper case characters : 4
#     No. of Lower case Characters : 33
#
# HINT: Two string methods that might prove useful: **.isupper()** and **.islower()**
#
# If you feel ambitious, explore the Collections module to solve this problem!

# %%
print(str.isupper('F'))
# Out:
# True

# %%
sum([True,False,True])
# thats freakin awesome
# Out:
# 2

# %%
s = 'Hello Mr. Rogers, how are you this fine Tuesday?'
# list(map(str.isupper, s))

# %%
" ".isupper()
# Out:
# False

# %%
" ".isalpha()
# Out:
# False

# %%
"!".isalpha()
# Out:
# False

# %%
    # return f"No. of Upper case characters : {sum(map(str.isupper,s))}\nNo. of Lower case Characters : {sum(map(str.islower,s))}"
    # best way

# %%
def up_low(s):
    lower=0
    upper=0
    for c in s:
      if c.isalpha():
        if c.islower():
          lower+=1
        elif c.isupper():
          upper+=1
      else:
        pass
    return(f"lower: {lower}, and upper: {upper}")

# %% [markdown]
# # or

# %%
def up_low(s):
  lower = sum(1 for c in s if c.islower())
  upper = sum(1 for c in s if c.isupper())
  return(f"lower: {lower}, and upper: {upper}")

# %%
# def up_low(s):
#     return count(filter(str.isupper, s))
 #   # NameError: name 'count' is not defined

# %%
# def up_low(s):
#     return filter(str.isupper, s).count(True)
##     AttributeError: 'filter' object has no attribute 'count'

# %%
# def up_low(s):
#     return len(filter(str.isupper, s))
## TypeError: object of type 'filter' has no len()

# %%
# def up_low(s):
#     return len(list(filter(str.isupper, s)))

# %% [raw]
# # or

# %%
# def up_low(s):
#     return list(map(str.isupper, s)).count(True)

# %%
s = 'Hello Mr. Rogers, how are you this fine Tuesday?'
print(up_low(s))
# Out:
# lower: 33, and upper: 4

# %% [markdown]
# ____
# **Write a Python function that takes a list and returns a new list with unique elements of the first list.**
#
#     Sample List : [1,1,1,1,2,2,3,3,3,3,4,5]
#     Unique List : [1, 2, 3, 4, 5]

# %%
def unique_list(lst):
    return list(set(lst))

# %%
unique_list([1,1,1,1,2,2,3,3,3,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ____
# **Write a Python function to multiply all the numbers in a list.**
#
#     Sample List : [1, 2, 3, -4]
#     Expected Output : -24
#
# https://www.geeksforgeeks.org/reduce-in-python
#
# https://www.geeksforgeeks.org/python-multiply-numbers-list-3-different-ways/

# %%
# from functools import reduce
# def multiply(numbers):  
#     return reduce(lambda x,y:x*y,numbers)

# %% [markdown]
# # or

# %%
# def multiply(numbers):  
#     result=1
#     for num in numbers:
#         result*=num
#     return result

# %% [markdown]
# # or

# %%
# import numpy as np
# def multiply(numbers):  
#     return np.prod(numbers)

# %% [markdown]
# ### Multiply all numbers in the list using prod function of math library

# %%
import math
def multiply(numbers):  
    return math.prod(numbers)

# %%
multiply([1,2,3,-4])
# Out:
# -24

# %% [markdown]
# ____
# **Write a Python function that checks whether a word or phrase is palindrome or not.**
#
# Note: A palindrome is word, phrase, or sequence that reads the same backward as forward, e.g., madam,kayak,racecar, or a phrase "nurses run". Hint: You may want to check out the .replace() method in a string to help out with dealing with spaces. Also google search how to reverse a string in Python, there are some clever ways to do it with slicing notation.

# %%
def palindrome(s):
   return s==s[::-1]

# %%
def palindrome(s):
  s = s.replace(" ","")
  return s==s[::-1]

# %%
palindrome('nur sesrun')
# Out:
# True

# %% [markdown]
# ____
# #### Hard:
#
# **Write a Python function to check whether a string is pangram or not. (Assume the string passed in does not have any punctuation)**
#
#     Note : Pangrams are words or sentences containing every letter of the alphabet at least once.
#     For example : "The quick brown fox jumps over the lazy dog"
#
# Hint: You may want to use .replace() method to get rid of spaces.
#
# Hint: Look at the [string module](https://stackoverflow.com/questions/16060899/alphabet-range-in-python)
#
# Hint: In case you want to use [set comparisons](https://medium.com/better-programming/a-visual-guide-to-set-comparisons-in-python-6ab7edb9ec41)

# %%
import string
def ispangram(s):
  return set(c.lower() for c in s if c.isalpha())==set(string.ascii_lowercase)

# %%
import string
def ispangram(s):
  return set(map(str.lower,filter(str.isalpha,s)))==set(string.ascii_lowercase)

# %%
st = set('abcd')
print(st.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 2
#       1 st = set('abcd')
# ----> 2 print(st.split())
#
# AttributeError: 'set' object has no attribute 'split'

# %%
# import string

# def ispangram(str1, alphabet=string.ascii_lowercase):
#     str1 = str1.lower()
#     str1 = str1.replace(' ','')
#     #  we cant sort a set
#     st1 = list(set(str1))
#     st1.sort()
#     return ''.join(st1)==alphabet

# %%
# there is no need to sort things out, just directly compare 2 sets

# %%
import string

def ispangram(str1, alphabet=string.ascii_lowercase):
    str1 = str1.lower()
    str1 = str1.replace(' ','')
    # print(set(alphabet))
    # print(set(str1))
    return set(alphabet) == set(str1)

# %% [markdown]
# You can use the set() function to create set objects using the given lists and then compare the sets for equality using the == operator. The order of the original list items is not important, because the == operator returns true when each set contains identical items in any order.

# %%
ispangram("The quick brown fox jumps over the lazy dog")
# Out:
# True

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %% [markdown]
# #### Great Job!

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
@interact(x=(1,100,1))
def func(x=25):
  return x**2
# Out:
# interactive(children=(IntSlider(value=25, description='x', min=1), Output()), _dom_classes=('widget-interact',…

# %%
def func(x=5):
  return x**2

func = interact(func,x=widgets.IntSlider(value=50,min=1, max =100, step=2))
# Out:
# interactive(children=(IntSlider(value=50, description='x', min=1, step=2), Output()), _dom_classes=('widget-in…

# %%
func()
# Out:
# 25

# %%
func(4)
# Out:
# 16

# %%
@interact(x=6.0)
def func(x=5):
  return x
# Out:
# interactive(children=(FloatSlider(value=6.0, description='x', max=18.0, min=-6.0), Output()), _dom_classes=('w…

# %%
@interact(x=(3.0,11,.1))
def func(x=5):
  return x
# Out:
# interactive(children=(FloatSlider(value=5.0, description='x', max=11.0, min=3.0), Output()), _dom_classes=('wi…

# %%
@interact(x=[1,2,3,4])
def func(x=5):
  return x
# Out:
# interactive(children=(Dropdown(description='x', options=(1, 2, 3, 4), value=1), Output()), _dom_classes=('widg…

# %%
# @interact(x=(1,2,3,4,5))
# def func(x=5):
#   return x

#error

# %%
@interact(x="Hello I am Jatin!!")
def func(x=5):
  return x
# Out:
# interactive(children=(Text(value='Hello I am Jatin!!', description='x'), Output()), _dom_classes=('widget-inte…

# %%
@interact(x=["Hi","There"])
def func(x=5):
  return x
# Out:
# interactive(children=(Dropdown(description='x', options=('Hi', 'There'), value='Hi'), Output()), _dom_classes=…

# %%
@interact(x=True)
def func(x=5):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x=5):
  return x
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=15, min=-5), Output()), _dom_classes=('widget-in…

# %%
@interact(x={'name':"Jatin","age":26,"work":"Business and study for fun"})
def func(x=5):
  return x
# Out:
# interactive(children=(Dropdown(description='x', options={'name': 'Jatin', 'age': 26, 'work': 'Business and stu…

# %%
@interact(x=7)
def func(x):
  return x

func(20)
# Out:
# interactive(children=(IntSlider(value=7, description='x', max=21, min=-7), Output()), _dom_classes=('widget-in…
# 20

# %%
@interact(x=fixed(50),y=True)
def func(x,y):
  return f"x is {x} and y is {y}"
# Out:
# interactive(children=(Checkbox(value=True, description='y'), Output()), _dom_classes=('widget-interact',))

# %%
func(100,0)
# Out:
# 'x is 100 and y is 0'

# %%
def func(x,y):
  return f"x is {x} and y is {y}"

func = interact(func,x=fixed(50),y=True)
# Out:
# interactive(children=(Checkbox(value=True, description='y'), Output()), _dom_classes=('widget-interact',))

# %%
func(500,50)
# Out:
# 'x is 500 and y is 50'

# %%
# @interact(x=fixed(50),y=(1,100,1,50)) #tuple shorthand 2/3 arguments, no default value
@interact (x=fixed(50),y=True,z=(1,100,1))
def func(x,y,z):
  return f"x is {x} and y is {y} and z is {z}"
# Out:
# interactive(children=(Checkbox(value=True, description='y'), IntSlider(value=50, description='z', min=1), Outp…

# %%
@interact (x=fixed(50),y=True,z=(1,100,1))
def func(x,y,z):
  print(f"x is {x} and y is {y} and z is {z}")
# Out:
# interactive(children=(Checkbox(value=True, description='y'), IntSlider(value=50, description='z', min=1), Outp…

# %%
from IPython.display import display

# %%
def func(x):
  return x

interact(func,x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.func(x)>

# %%
def func(x):
  return x

interact(func,x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
# interactive

# %%
def func(x,y):
  return (x,y)

w = interactive(func,x=(1,100,1),y=True)

# %%
print(w)
# Out:
# interactive(children=(IntSlider(value=50, description='x', min=1), Checkbox(value=True, description='y'), Output()), _dom_classes=('widget-interact',))

# %%
w.children
# Out:
# (IntSlider(value=50, description='x', min=1),
#  Checkbox(value=True, description='y'),
#  Output())

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=50, description='x', min=1), Checkbox(value=True, description='y'), Outp…

# %%
# now try with display

# %%
def func(x,y):
  display(x,y)
  return (x,y)

w = interactive(func,x=(1,100,1),y=True)

# %%
w.children
# Out:
# (IntSlider(value=50, description='x', min=1),
#  Checkbox(value=True, description='y'),
#  Output())

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=50, description='x', min=1), Checkbox(value=True, description='y'), Outp…

# %%
@interactive(x=10)
def func(x):
  return x

# cant use it like this
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 @interactive(x=10)
#       2 def func(x):
#       3   return x
#       5 # cant use it like this
#
# TypeError: interactive.__init__() missing 1 required positional argument: '_interactive__interact_f'

# %%
@interact(x=10)
def func(x):
  return x

#but this ofc works
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
def func(x=10,y=False):
  display(x,y)
  return (x,y)

w = interactive(func,x=(1,100,1),y=True)

# %%
w.children
# Out:
# (IntSlider(value=10, description='x', min=1),
#  Checkbox(value=True, description='y'),
#  Output())

# %%
w.kwargs
# Out:
# {'x': 10, 'y': True}

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=10, description='x', min=1), Checkbox(value=True, description='y'), Outp…

# %%
w.kwargs
# Out:
# {'x': 64, 'y': True}

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=64, description='x', min=1), Checkbox(value=True, description='y'), Outp…

# %%
w.kwargs
# Out:
# {'x': 45, 'y': True}

# %%
w.result
# Out:
# (45, True)

# %%
# Using a decorator!
@interact(x=True, y=(1,100,.5))
def g(x, y):
    return (x, round(y,2))
# Out:
# interactive(children=(Checkbox(value=True, description='x'), FloatSlider(value=50.0, description='y', min=1.0,…

# %% [markdown]
# You can also specify widget abbreviations using [function annotations](https://docs.python.org/3/tutorial/controlflow.html#function-annotations).
#
# Define a function with a checkbox widget abbreviation for the argument `x`.

# %%
def f(x:True):  # type hint only
    return x

# %% [markdown]
# Then, because the widget abbreviation has already been defined, you can call `interact` with a single argument.

# %%
interact(f);
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
interact(f,x=False);
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
interact(f,x=True);
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
f()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 f()
#
# TypeError: f() missing 1 required positional argument: 'x'

# %%
f(True)
# Out:
# True

# %%
f(False)
# Out:
# False

# %%
def f(x=True):  # Python 3 only
    return x

# %%
f()
# Out:
# True

# %%
f(False)
# Out:
# False

# %%
f(True)
# Out:
# True

# %%
interact(f);
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
interact(f,x=False);
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
interact(f,x=True);
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x:True):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
func()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 func()
#
# TypeError: func() missing 1 required positional argument: 'x'

# %%
func(False)
# Out:
# False

# %%
@interact()
def func(x=True):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
func()
# Out:
# True

# %%
func(False)
# Out:
# False

# %%
@interact(x:False)
def func(x:True):
  return x
# Out:
#   Cell In[23], line 1
#     @interact(x:False)
#                ^
# SyntaxError: invalid syntax

# %%
@interact(x=False)
def func(x:True):
  return x
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact(x=False)
def func(x=True):
  return x
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x=True):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x=False):
  return x
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x:True):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x:False):
  return x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 @interact()
#       2 def func(x:False):
#       3   return x
#
# File j:\Development\Python\Anaconda\envs\pyZeroToHeroJosePortilla\Lib\site-packages\ipywidgets\widgets\interaction.py:536, in _InteractFactory.__call__(self, _InteractFactory__interact_f, **kwargs)
#     528     return self
#     530 # positional arg support in: https://gist.github.com/8851331
#     531 # Handle the cases 1 and 2
#     532 # 1. interact(f, **kwargs)
#     533 # 2. @interact
#     534 #    def f(*args, **kwargs):
#     535 #        ...
# --> 536 w = self.widget(f)
#     537 try:
#     538     f.widget = w
#
# File j:\Development\Python\Anaconda\envs\pyZeroToHeroJosePortilla\Lib\site-packages\ipywidgets\widgets\interaction.py:452, in _InteractFactory.widget(self, f)
#     436 def widget(self, f):
#     437     """
# ...

# %%
@interact()
def func(x:bool):
  return x
# Out:
# interactive(children=(Checkbox(value=False, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact()
def func(x:str):
  return x
# Out:
# interactive(children=(Text(value='', description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact(x=True)
def func(x:bool):
  return x
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %% [markdown]
# # Widget Basics
#
# In this lecture we will continue to build off our understanding of **interact** and **interactive** to begin using full widgets!

# %% [markdown]
# ## What are widgets?

# %% [markdown]
# Widgets are eventful python objects that have a representation in the browser, often as a control like a slider, textbox, etc.

# %% [markdown]
# ## What can they be used for?

# %% [markdown]
# You can use widgets to build **interactive GUIs** for your notebooks.
# You can also use widgets to **synchronize stateful and stateless information** between Python and JavaScript.

# %% [markdown]
# ## Using widgets

# %% [markdown]
# To use the widget framework, you need to import `ipywidgets`.

# %%
5+5
# Out:
# 10

# %%
import ipywidgets as widgets

# %% [markdown]
# ### repr

# %% [markdown]
# Widgets have their own display `repr` which allows them to be displayed using IPython's display framework. Constructing and returning an `IntSlider` automatically displays the widget (as seen below). Widgets are displayed inside the output area below the code cell. Clearing cell output will also remove the widget.

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %% [markdown]
# ### display()

# %% [markdown]
# You can also explicitly display the widget using `display(...)`.

# %%
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %% [markdown]
# ### Multiple display() calls

# %% [markdown]
# If you display the same widget twice, the displayed instances in the front-end will remain in sync with each other. Try dragging the slider below and watch the slider above.

# %%
display(w)
# Out:
# IntSlider(value=0)

# %% [markdown]
# ### Closing widgets

# %% [markdown]
# You can close a widget by calling its `close()` method.

# %%
display(w)
# Out:
# IntSlider(value=48)

# %%
w.close()

# %%
display(w)
# Out:
# IntSlider(value=48)

# %%
w.value
# Out:
# 48

# %%
w.value = 56

# %%
w.value
# Out:
# 56

# %% [markdown]
# ## Widget properties

# %% [markdown]
# All of the IPython widgets share a similar naming scheme. To read the value of a widget, you can query its `value` property.

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.value
# Out:
# 0

# %% [markdown]
# Similarly, to set a widget's value, you can set its `value` property.

# %%
w.value = 100

# %% [markdown]
# ### Keys

# %% [markdown]
# In addition to `value`, most widgets share `keys`, `description`, and `disabled`. To see the entire list of synchronized, stateful properties of any specific widget, you can query the `keys` property.

# %%
w.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'behavior',
#  'continuous_update',
#  'description',
#  'description_allow_html',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'tabbable',
#  'tooltip',
#  'value']

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.min=50
w.max = 100
w.value = 75

# %%
w.value=50

# %%
w.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'behavior',
#  'continuous_update',
#  'description',
#  'description_allow_html',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'tabbable',
#  'tooltip',
#  'value']

# %%
w.style
# Out:
# SliderStyle()

# %% [markdown]
# ### Shorthand for setting the initial values of widget properties

# %% [markdown]
# While creating a widget, you can set some or all of the initial values of that widget by defining them as keyword arguments in the widget's constructor (as seen below).

# %%
widgets.Text(value='Hello World!', disabled=True)
# Out:
# Text(value='Hello World!', disabled=True)

# %%
widgets.Text(value='Hello World!', disabled=False)
# Out:
# Text(value='Hello World!')

# %% [markdown]
# ## Linking two similar widgets

# %% [markdown]
# If you need to display the same value two different ways, you'll have to use two different widgets. Instead of attempting to manually synchronize the values of the two widgets, you can use the `link` or `jslink` function to link two properties together (the difference between these is discussed in Widget Events).  Below, the values of two widgets are linked together.

# %%
b = widgets.FloatSlider(value =5.6)
a = widgets.FloatText(value=5.8)

display(a,b)

# mylink = widgets.jslink((b, 'value'), (a, 'value'))
#whatever comes first linked to trhat valuew initially

# Link the current values
max_link = widgets.jslink((a, 'value'), (b, 'max'))
# value_link = widgets.jslink((a, 'value'), (b, 'value'))
# Link the maximum limits
# max_link = widgets.jslink((a, 'max'), (b, 'max')) #error,  floattext has not max key
# Out:
# FloatText(value=5.8)
# FloatSlider(value=5.6)

# %%
a.value = 60

# %%
print(a.value,b.value)
# Out:
# 60.0 60.0

# %%
b.value = 50

# %%
print(a.value,b.value)
# Out:
# 50.0 50.0

# %% [markdown]
# ### Unlinking widgets

# %% [markdown]
# Unlinking the widgets is simple.  All you have to do is call `.unlink` on the link object. Try changing one of the widgets above after unlinking to see that they can be independently changed.

# %%
mylink.unlink()

# %%
mylink.link()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mylink.link()
#
# AttributeError: 'Link' object has no attribute 'link'

# %% [markdown]
# # Conclusion
#
# You should now be beginning to have an understanding of how Widgets can interact with each other and how you can begin to specify widget details.

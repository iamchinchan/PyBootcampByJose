# %% [markdown]
# # Collections Module
#
# The collections module is a built-in module that implements specialized container data types providing alternatives to Python’s general purpose built-in containers. We've already gone over the basics: dict, list, set, and tuple.
#
# Now we'll learn about the alternatives that the collections module provides.
#
# ## Counter
#
# *Counter* is a *dict* subclass which helps count hashable objects. Inside of it elements are stored as dictionary keys and the counts of the objects are stored as the value.
#
# Let's see how it can be used:

# %%
from collections import Counter

# %% [markdown]
# **Counter() with lists**

# %%
lst = [1,2,2,2,2,3,3,3,1,2,1,12,3,2,32,1,21,1,223,1]

c = Counter(lst)
print(id(c))
print(id(Counter(lst)))
# Out:
# 2715115524656
# 2715117764096

# %%
type(Counter(lst))
# Out:
# collections.Counter

# %%
c
# Out:
# Counter({1: 6, 2: 6, 3: 4, 12: 1, 32: 1, 21: 1, 223: 1})

# %%
type(c)
# Out:
# collections.Counter

# %%
Counter(lst)[5]
# Out:
# 0

# %%
Counter(lst)[1]
# Out:
# 6

# %%
c[1]
# Out:
# 6

# %%
print(id(c))
print(id(Counter(lst)))
print(id(Counter(lst)))
# Out:
# 2715115524656
# 2715117475216
# 2715115684944

# %%
del Counter(lst)
# Out:
#   Cell In[12], line 1
#     del Counter(lst)
#         ^
# SyntaxError: cannot delete function call

# %%
del c

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c = Counter(lst)
c
# Out:
# Counter({1: 6, 2: 6, 3: 4, 12: 1, 32: 1, 21: 1, 223: 1})

# %% [markdown]
# **Counter with strings**

# %%
type(Counter('aabsbsbsbhshhbbsbs'))
# Out:
# collections.Counter

# %%
Counter('aabsbsbsbhshhbbsbs')
# Out:
# Counter({'b': 7, 's': 6, 'h': 3, 'a': 2})

# %% [markdown]
# **Counter with words in a sentence**

# %%
s = 'How many times does each word show up in this sentence word times each each word'

words = s.split()

Counter(words)
# Out:
# Counter({'each': 3,
#          'word': 3,
#          'times': 2,
#          'How': 1,
#          'many': 1,
#          'does': 1,
#          'show': 1,
#          'up': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1})

# %%
# Methods with Counter()
c = Counter(words)

c.most_common(2)
# Out:
# [('each', 3), ('word', 3)]

# %%
c.keys()
# Out:
# dict_keys(['How', 'many', 'times', 'does', 'each', 'word', 'show', 'up', 'in', 'this', 'sentence'])

# %%
c.values()
# Out:
# dict_values([1, 1, 2, 1, 3, 3, 1, 1, 1, 1, 1])

# %%
c.items()
# Out:
# dict_items([('How', 1), ('many', 1), ('times', 2), ('does', 1), ('each', 3), ('word', 3), ('show', 1), ('up', 1), ('in', 1), ('this', 1), ('sentence', 1)])

# %%
sum(c.values())
# Out:
# 16

# %%
len(words)
# Out:
# 16

# %%
c
# Out:
# Counter({'each': 3,
#          'word': 3,
#          'times': 2,
#          'How': 1,
#          'many': 1,
#          'does': 1,
#          'show': 1,
#          'up': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1})

# %%
len(c)
# Out:
# 11

# %%
c.clear()

# %%
c
# Out:
# Counter()

# %%
c.values()
# Out:
# dict_values([])

# %%
c = Counter(words)

# %%
c
# Out:
# Counter({'each': 3,
#          'word': 3,
#          'times': 2,
#          'How': 1,
#          'many': 1,
#          'does': 1,
#          'show': 1,
#          'up': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1})

# %%
list(c)
# will just create list of keys
# Out:
# ['How',
#  'many',
#  'times',
#  'does',
#  'each',
#  'word',
#  'show',
#  'up',
#  'in',
#  'this',
#  'sentence']

# %%
list(c.values())
# Out:
# [1, 1, 2, 1, 3, 3, 1, 1, 1, 1, 1]

# %%
set(c.values())
# Out:
# {1, 2, 3}

# %%
set(c)
   # set of keys of c
# Out:
# {'How',
#  'does',
#  'each',
#  'in',
#  'many',
#  'sentence',
#  'show',
#  'this',
#  'times',
#  'up',
#  'word'}

# %%
len(set(c))
# Out:
# 11

# %%
len(c)
# Out:
# 11

# %%
dict(c)
# Out:
# {'How': 1,
#  'many': 1,
#  'times': 2,
#  'does': 1,
#  'each': 3,
#  'word': 3,
#  'show': 1,
#  'up': 1,
#  'in': 1,
#  'this': 1,
#  'sentence': 1}

# %%
c.items()
# Out:
# dict_items([('How', 1), ('many', 1), ('times', 2), ('does', 1), ('each', 3), ('word', 3), ('show', 1), ('up', 1), ('in', 1), ('this', 1), ('sentence', 1)])

# %%
type(c)
# Out:
# collections.Counter

# %%
c.most_common()[:-3:-1]
# leat 2
# Out:
# [('sentence', 1), ('this', 1)]

# %%
c.most_common()[::-1]
# leat common
# Out:
# [('sentence', 1),
#  ('this', 1),
#  ('in', 1),
#  ('up', 1),
#  ('show', 1),
#  ('does', 1),
#  ('many', 1),
#  ('How', 1),
#  ('times', 2),
#  ('word', 3),
#  ('each', 3)]

# %%
c.most_common()
# Out:
# [('each', 3),
#  ('word', 3),
#  ('times', 2),
#  ('How', 1),
#  ('many', 1),
#  ('does', 1),
#  ('show', 1),
#  ('up', 1),
#  ('in', 1),
#  ('this', 1),
#  ('sentence', 1)]

# %%
dict([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 dict([1,2,3])
#
# TypeError: object is not iterable
# Cannot convert dictionary update sequence element #0 to a sequence

# %%
d = dict([(1,4),(2,2),(3,5),(5,0),(5,3),(6,0),(7,-1)])
print(d)
cd = Counter(d)
print(cd)
# Out:
# {1: 4, 2: 2, 3: 5, 5: 3, 6: 0, 7: -1}
# Counter({3: 5, 1: 4, 5: 3, 2: 2, 6: 0, 7: -1})

# %%
cd.most_common()[::-1]
# Out:
# [(7, -1), (6, 0), (2, 2), (5, 3), (1, 4), (3, 5)]

# %%
cd+=Counter()
cd.most_common()[::-1]
# Out:
# [(2, 2), (5, 3), (1, 4), (3, 5)]

# %% [markdown]
# ## Common patterns when using the Counter() object

# %% [markdown]
#     sum(c.values())                 # total of all counts
#     c.clear()                       # reset all counts
#     list(c)                         # list unique elements
#     set(c)                          # convert to a set
#     dict(c)                         # convert to a regular dictionary
#     c.items()                       # convert to a list of (elem, cnt) pairs
#     Counter(dict(list_of_pairs))    # convert from a list of (elem, cnt) pairs
#     c.most_common()[:-n-1:-1]       # n least common elements
#     c += Counter()                  # remove zero and negative counts

# %% [markdown]
# ## defaultdict
#
# defaultdict is a dictionary-like object which provides all methods provided by a dictionary but takes a first argument (default_factory) as a default data type for the dictionary. Using defaultdict is faster than doing the same using dict.set_default method.
#
# **A defaultdict will never raise a KeyError. Any key that does not exist gets the value returned by the default factory.**

# %%
from collections import defaultdict

# %%
d = {}

# %%
d['one']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 d['one']
#
# KeyError: 'one'

# %%
d  = defaultdict(object)

# %%
d['one']

# %%
print(d)
# Out:
# defaultdict(<class 'object'>, {'one': <object object at 0x0000027829E4B530>})

# %%
for item in d.items():
    print(item)
# Out:
# ('one', <object object at 0x0000027829E4B530>)

# %%
d.items()
# Out:
# dict_items([('one', <object object at 0x0000027829E4B530>)])

# %% [markdown]
# Can also initialize with default values:

# %%
d = defaultdict(lambda: 0)

# %%
d['one']
# Out:
# 0

# %%
for item in d.items():
    print (item)
# Out:
# ('one', 0)

# %%
d.items()
# Out:
# dict_items([('one', 0)])

# %% [markdown]
# # namedtuple
# The standard tuple uses numerical indexes to access its members, for example:

# %%
t = (12,13,14)

# %%
t[0]
# Out:
# 12

# %% [markdown]
# For simple use cases, this is usually enough. On the other hand, remembering which index should be used for each value can lead to errors, especially if the tuple has a lot of fields and is constructed far from where it is used. A namedtuple assigns names, as well as the numerical index, to each member.
#
# Each kind of namedtuple is represented by its own class, created by using the namedtuple() factory function. The arguments are the name of the new class and a string containing the names of the elements.
#
# You can basically think of namedtuples as a very quick way of creating a new object/class type with some attribute fields.
# For example:

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Doggy',['age','breed','name'])

sam = Dog(age=2,breed='Lab',name='Sammy')

frank = Dog(age=2,breed='Shepard',name="Frankie")

# %% [markdown]
# We construct the namedtuple by first passing the object type name (Doggy) and then passing a list with the variety of fields as a string with commas
# between the field names. We can then call on the various attributes:

# %%
type(sam)
# Out:
# __main__.Doggy

# %%
sam
# Out:
# Doggy(age=2, breed='Lab', name='Sammy')

# %%
sam.age
# Out:
# 2

# %%
sam.breed
# Out:
# 'Lab'

# %%
sam[0]
# Out:
# 2

# %%
sam.count(2)
# Out:
# 1

# %%
sam.index('Lab')
# Out:
# 1

# %%
sam.add = 5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sam.add = 5
#
# AttributeError: 'Doggy' object has no attribute 'add' and no __dict__ for setting new attributes

# %%
sam.age
# Out:
# 2

# %%
sam.age=5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 sam.age=5
#
# AttributeError: can't set attribute

# %%
sam['age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 sam['age']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
sam[0]
# Out:
# 2

# %%
sam[0]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 sam[0]=4
#
# TypeError: 'Doggy' object does not support item assignment

# %%
sam.age = 4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 sam.age = 4
#
# AttributeError: can't set attribute

# %%
sam[1]
# Out:
# 'Lab'

# %%
sam[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 sam[5]
#
# IndexError: tuple index out of range

# %%
tpl = (1,2,3)

# %%
tpl[1]
# Out:
# 2

# %%
tpl[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 tpl[3]
#
# IndexError: tuple index out of range

# %% [markdown]
# ## Conclusion
#
# Hopefully you now see how incredibly useful the collections module is in Python and it should be your go-to module for a variety of common tasks!
